# %% [markdown]
# ## Importando as bibliotecas

# %%
import pandas as pd 
import numpy as np 
from sqlalchemy import create_engine
from pyodbc import drivers
from dotenv import load_dotenv
import os

# %% [markdown]
# ## Verificando os Drivers

# %%
for driver in drivers():
    print(driver)
# Out:
# SQL Server
# PostgreSQL ODBC Driver(ANSI)
# PostgreSQL ODBC Driver(UNICODE)

# %% [markdown]
# ## Definindo a variável para o arquivo csv e visualizando a mesma.

# %%
data01 = pd.read_csv(r'./data/data01.csv')

print(data01.to_string())
# Out:
#     ID CLIENTE REPRESENTANTE RESPONSÁVEL ANALISTA RESPONSAVEL STATUS DO CLIENTE  TIPO DE CLIENTE              NOME CLIENTE               LOGRADOURO, NUMERO            BAIRRO       MUNICIPIO ESTADO        CEP        REGIÃO            CNPJ/CPF
# 0            1                 Ana Silva       Carlos Pereira             Ativo  Pessoa Jurídica         Empresa Alfa Ltda              Rua das Flores, 123  Jardim Primavera       São Paulo     SP        NaN       Sudeste  12.345.678/0001-90
# 1            2            Pedro Oliveira        Mariana Souza           Inativo    Pessoa Física             João da Silva              Avenida Brasil, 456            Centro  Rio de Janeiro     RJ  20010-020       Sudeste      123.456.789-01
# 2            3           Carla Rodrigues         Lucas Santos             Ativo  Pessoa Jurídica        Beta Indústria S/A           Alameda dos Anjos, 789         Boa Vista  Belo Horizonte     MG  30123-456       Sudeste  98.765.432/0001-10
# ...

# %% [markdown]
# ## Fazendo a mudança dos Nan na coluna CEP para 0.

# %%
data01['CEP'] = data01['CEP'].fillna(0)
print(data01.to_string())
# Out:
#     ID CLIENTE REPRESENTANTE RESPONSÁVEL ANALISTA RESPONSAVEL STATUS DO CLIENTE  TIPO DE CLIENTE              NOME CLIENTE               LOGRADOURO, NUMERO            BAIRRO       MUNICIPIO ESTADO        CEP        REGIÃO            CNPJ/CPF
# 0            1                 Ana Silva       Carlos Pereira             Ativo  Pessoa Jurídica         Empresa Alfa Ltda              Rua das Flores, 123  Jardim Primavera       São Paulo     SP          0       Sudeste  12.345.678/0001-90
# 1            2            Pedro Oliveira        Mariana Souza           Inativo    Pessoa Física             João da Silva              Avenida Brasil, 456            Centro  Rio de Janeiro     RJ  20010-020       Sudeste      123.456.789-01
# 2            3           Carla Rodrigues         Lucas Santos             Ativo  Pessoa Jurídica        Beta Indústria S/A           Alameda dos Anjos, 789         Boa Vista  Belo Horizonte     MG  30123-456       Sudeste  98.765.432/0001-10
# ...

# %% [markdown]
# ## Definindo a variável para o arquivo xlsx e visualizando a mesma.

# %%
data02 = pd.read_excel(r'./data/data02.xlsx')

print(data02.to_string())
# Out:
#    ID CLIENTE REPRESENTANTE RESPONSÁVEL ANALISTA RESPONSAVEL STATUS DO CLIENTE  TIPO DE CLIENTE                NOME CLIENTE         LOGRADOURO, NUMERO               BAIRRO      MUNICIPIO ESTADO        CEP        REGIÃO            CNPJ/CPF
# 0          21          Sabrina Oliveira       Leonardo Costa             Ativo  Pessoa Jurídica  Sol Nascente Comércio Ltda     Rua dos Girassóis, 890      Flores do Campo       Campinas     SP  13088-000       Sudeste  90.123.456/0001-00
# 1          22         Marcelo Fernandes       Camila Pereira             Ativo    Pessoa Física           Ana Beatriz Souza    Avenida das Acácias, 15           Boa Viagem         Recife     PE  51020-000      Nordeste      098.765.432-11
# 2          23             Juliana Alves         Rafael Gomes          Pendente  Pessoa Jurídica     Lua Crescente Indústria        Estrada Velha, KM 3  Distrito Industrial      Joinville     SC  89219-710           Sul  10.234.567/0001-20
# ...

# %% [markdown]
# ## Padrozinando as colunas, removendo espaços e vírgulas.

# %%
data01.columns = data01.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(',', '_').str.replace('/', '_')
data02.columns = data02.columns.str.strip().str.lower().str.replace(' ', '_').str.replace(',', '_').str.replace('/', '_')

# %% [markdown]
# ## Mesclando o arquivo csv e o xlsx.

# %%
mergeData_01_02 = pd.concat([data01, data02], ignore_index="True")

print(mergeData_01_02.to_string())
# Out:
#     id_cliente representante_responsável analista_responsavel status_do_cliente  tipo_de_cliente                nome_cliente               logradouro__numero               bairro       municipio estado        cep        região            cnpj_cpf
# 0            1                 Ana Silva       Carlos Pereira             Ativo  Pessoa Jurídica           Empresa Alfa Ltda              Rua das Flores, 123     Jardim Primavera       São Paulo     SP          0       Sudeste  12.345.678/0001-90
# 1            2            Pedro Oliveira        Mariana Souza           Inativo    Pessoa Física               João da Silva              Avenida Brasil, 456               Centro  Rio de Janeiro     RJ  20010-020       Sudeste      123.456.789-01
# 2            3           Carla Rodrigues         Lucas Santos             Ativo  Pessoa Jurídica          Beta Indústria S/A           Alameda dos Anjos, 789            Boa Vista  Belo Horizonte     MG  30123-456       Sudeste  98.765.432/0001-10
# ...

# %% [markdown]
# ## Criando a conexão com o banco de dados

# %%
load_dotenv()

user = os.getenv('DB_USER')
password = os.getenv('DB_PASSWORD')
host = os.getenv('DB_HOST', 'localhost')
port = os.getenv('DB_PORT', '5432')
database = os.getenv('DB_NAME')

engine = create_engine(f'postgresql+psycopg2://{user}:{password}@{host}:{port}/{database}')
con = engine.connect()

# %% [markdown]
# ## importando os dados para a tabela

# %%
mergeData_01_02.to_sql('clientes_etl', con=con, index=False, if_exists='append')
# Out:
# 30
